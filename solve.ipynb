# %%
import sympy as sp

R, S, T = sp.symbols('R S T', real=True)
sqrt = sp.sqrt

FS_num = S**2 + (R+T)*S - 3*R*T

FR_num = (R+1)**2*(R**2 + R*(S+T) - S*T) \
         - (R+S)*(2*sqrt(R)*sqrt(T)*sqrt(2*R+1)*sqrt(R+T+1)
                  + R*(2*T - (R+1)*(R+T)))

res_RS = sp.resultant(FS_num, FR_num, S)

res_l = 28*R**(9/2)*T**(3/2)*sqrt(2*R + 1)*sqrt(R + T + 1) + 4*R**(7/2)*T**(5/2)*sqrt(2*R + 1)*sqrt(R + T + 1) + 40*R**(7/2)*T**(3/2)*sqrt(2*R + 1)*sqrt(R + T + 1) - 40*R**(5/2)*T**(5/2)*sqrt(2*R + 1)*sqrt(R + T + 1) + 12*R**(5/2)*T**(3/2)*sqrt(2*R + 1)*sqrt(R + T + 1) - 12*R**(3/2)*T**(5/2)*sqrt(2*R + 1)*sqrt(R + T + 1) 
res_w = - 12*R**7*T - 34*R**6*T + 44*R**5*T**2 - 34*R**5*T + 6*R**4*T**3 + 48*R**4*T**2 - 14*R**4*T - 54*R**3*T**3 - 4*R**3*T**2 - 2*R**3*T - 30*R**2*T**3 - 8*R**2*T**2 - 2*R*T**3

res_l2 = sp.simplify(res_l * res_l)
res_w2 = sp.simplify(res_w * res_w)

equation = res_l2 - res_w2

e1 = -4*R**2*T**2*(6*R**6 + 17*R**5 - 22*R**4*T + 17*R**4 - 3*R**3*T**2 - 24*R**3*T + 7*R**3 + 27*R**2*T**2 + 2*R**2*T + R**2 + 15*R*T**2 + 4*R*T + T**2)**2 
e2 = 16*(2*R + 1)*(R + T + 1)*(-3*R**1.5*T**2.5 + 3*R**2.5*T**1.5 - 10*R**2.5*T**2.5 + 10*R**3.5*T**1.5 + R**3.5*T**2.5 + 7*R**4.5*T**1.5)**2

e2 = 16*(2*R + 1)*(R + T + 1)*(-3*R**1*T**2 + 3*R**2*T**1 - 10*R**2*T**2 + 10*R**3*T**1 + R**3*T**2 + 7*R**4*T**1)**2 * (R*T)

equation = e1 + e2

equation
# Out:
# -4*R**2*T**2*(6*R**6 + 17*R**5 - 22*R**4*T + 17*R**4 - 3*R**3*T**2 - 24*R**3*T + 7*R**3 + 27*R**2*T**2 + 2*R**2*T + R**2 + 15*R*T**2 + 4*R*T + T**2)**2 + R*T*(32*R + 16)*(R + T + 1)*(7*R**4*T + R**3*T**2 + 10*R**3*T - 10*R**2*T**2 + 3*R**2*T - 3*R*T**2)**2

# %%
import sympy as sp

R, S, T = sp.symbols('R S T', real=True)
sqrt = sp.sqrt

FT_num1 = (
    -4*R*sqrt(S)*T*sqrt(R+T+S)*sqrt(R+T+1)
    + (R + T)**2*(S + T)*sqrt(T)*sqrt(T+2)
)

FT_num2 = (2*R - (R + T)*(T + 1))*(-R*S + T**2 + T*(R + S))

# FT_num1 = FT_num2

FT_num1 = sp.expand(FT_num1 * FT_num1)
FT_num2 = sp.simplify(FT_num2 * FT_num2)

FT_num1_1 = R**4*S**2*T**2 + 2*R**4*S**2*T + 2*R**4*S*T**3 + 20*R**4*S*T**2 + R**4*T**4 + 2*R**4*T**3+ 4*R**3*S**2*T**3 + 24*R**3*S**2*T**2 + 8*R**3*S*T**4 + 48*R**3*S*T**3  + 16*R**3*S*T**2 + 4*R**3*T**5 + 8*R**3*T**4+ 6*R**2*S**2*T**4 + 28*R**2*S**2*T**3 + 16*R**2*S**2*T**2 + 12*R**2*S*T**5 + 40*R**2*S*T**4 + 16*R**2*S*T**3 + 6*R**2*T**6 + 12*R**2*T**5 + 4*R*S**2*T**5 + 8*R*S**2*T**4 + 8*R*S*T**6 + 16*R*S*T**5 + 4*R*T**7 + 8*R*T**6 + S**2*T**6 + 2*S**2*T**5 + 2*S*T**7 + 4*S*T**6 + T**8 + 2*T**7
FT_num1_2 = (sqrt(S)*sqrt(T)*sqrt(T+2)*sqrt(R+S+T)*sqrt(R+T+1))*(-8*R**3*S*T - 8*R**3*T**2 - 16*R**2*S*T**2 - 16*R**2*T**3  - 8*R*S*T**3 - 8*R*T**4) 
# FT_num1 = FT_num1_1 + FT_num1_2

#  -FT_num1_2 = FT_num1_1 - FT_num2

leftpart = sp.simplify(FT_num1_2 * FT_num1_2)
rightpart = sp.simplify((FT_num1_1 - FT_num2) * (FT_num1_1 - FT_num2))

# leftpart = rightpart

equation_second = leftpart - rightpart

equation_second
# Out:
# 64*R**2*S*T**3*(T + 2)*(R + S + T)*(R + T + 1)*(R**2*S + R**2*T + 2*R*S*T + 2*R*T**2 + S*T**2 + T**3)**2 - (R**4*S**2*T**2 + 2*R**4*S**2*T + 2*R**4*S*T**3 + 20*R**4*S*T**2 + R**4*T**4 + 2*R**4*T**3 + 4*R**3*S**2*T**3 + 24*R**3*S**2*T**2 + 8*R**3*S*T**4 + 48*R**3*S*T**3 + 16*R**3*S*T**2 + 4*R**3*T**5 + 8*R**3*T**4 + 6*R**2*S**2*T**4 + 28*R**2*S**2*T**3 + 16*R**2*S**2*T**2 + 12*R**2*S*T**5 + 40*R**2*S*T**4 + 16*R**2*S*T**3 + 6*R**2*T**6 + 12*R**2*T**5 + 4*R*S**2*T**5 + 8*R*S**2*T**4 + 8*R*S*T**6 + 16*R*S*T**5 + 4*R*T**7 + 8*R*T**6 + S**2*T**6 + 2*S**2*T**5 + 2*S*T**7 + 4*S*T**6 + T**8 + 2*T**7 - (2*R - (R + T)*(T + 1))**2*(-R*S + T**2 + T*(R + S))**2)**2

# %%
res_2 = sp.resultant(FS_num, equation_second, S)
res_2
# Out:
# 2304*R**20*T**10 - 16512*R**20*T**9 + 31888*R**20*T**8 - 24256*R**20*T**7 + 7392*R**20*T**6 - 832*R**20*T**5 + 16*R**20*T**4 + 50688*R**19*T**11 - 236928*R**19*T**10 + 206592*R**19*T**9 + 23808*R**19*T**8 - 56832*R**19*T**7 + 13440*R**19*T**6 - 768*R**19*T**5 - 13824*R**18*T**13 + 455040*R**18*T**12 - 1084800*R**18*T**11 + 254208*R**18*T**10 + 981248*R**18*T**9 - 274560*R**18*T**8 - 21888*R**18*T**7 + 8704*R**18*T**6 - 207360*R**17*T**14 + 1847808*R**17*T**13 - 2144640*R**17*T**12 - 1620224*R**17*T**11 + 3226368*R**17*T**10 + 345600*R**17*T**9 - 414592*R**17*T**8 + 17664*R**17*T**7 + 20736*R**16
# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

R = sp.symbols('R')

fr_clean = sp.expand(fr)
f_lambd = sp.lambdify(R, fr_clean, "numpy")

x_vals = np.linspace(0.71, 0.72, 500)
y_vals = f_lambd(x_vals)

plt.figure(figsize=(8,5))
plt.plot(x_vals, y_vals, label="fr(R)")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("R")
plt.ylabel("fr(R)")
plt.title("График многочлена fr(R)")
plt.legend()
plt.grid(True)
plt.show()

# %%
factored = sp.factor(fr.as_expr())
factored
# Out:
# 281474976710656*R**84*(R + 1)**88*(2*R + 1)**4*(3*R + 1)**4*(9*R**4 + 72*R**3 + 186*R**2 + 144*R + 37)**8*(1296*R**8 - 3456*R**7 - 864*R**6 + 3504*R**5 + 1240*R**4 - 80*R**3 + 12*R**2 - 20*R + 1)*(104976*R**12 - 629856*R**11 + 297432*R**10 + 1561032*R**9 + 452385*R**8 - 840456*R**7 - 541476*R**6 + 53400*R**5 + 122758*R**4 + 25320*R**3 - 3132*R**2 - 864*R + 81)*(8503056*R**28 + 90699264*R**27 + 549864288*R**26 + 2007036144*R**25 + 3977068248*R**24 - 3605330736*R**23 - 61162076484*R**22 - 268029251748*R**21 - 767660640255*R**20 - 1607245644744*R**19 - 2464047202392*R**18 - 2491917197688*R**17 - 774879099300*R**16 + 2550192968232*R**15 + 5724058211280*R**14 + 6666750888192*R**13 + 5014804038534*R**12 + 2320032221304*R**11 + 314263704888*R**10 - 454766346552*R**9 - 436935228092*R**8 - 219990544088*R**7 - 74262031788*R**6 - 17746530716*R**5 - 3044701583*R**4 - 373535952*R**3 - 31040928*R**2 - 1278720*R + 20736)*(688747536*R**28 + 10560795552*R**27 + 95621116248*R**26 + 572463993672*R**25 
# ...

# %%
_, factors = sp.factor_list(factored)
fr2 = factors[-3][0]
fr2
# Out:
# 104976*R**12 - 629856*R**11 + 297432*R**10 + 1561032*R**9 + 452385*R**8 - 840456*R**7 - 541476*R**6 + 53400*R**5 + 122758*R**4 + 25320*R**3 - 3132*R**2 - 864*R + 81

# %%
rt = sp.nroots(fr2, n=100, maxsteps=1000)
rt
# Out:
# [0.1038310519780554820764064080814861910654742837596209075676475729102692267278765882637100852847127273,
#  0.1161997836888272584461712886317560412200046958443058993004995063086998005789748633884741086358334623,
#  0.5480897312994370978900012877631813160084044396799103611442998925205442175776264225270324635920372757,
#  0.7133077137962365048848458379424144097340174463728663791558978931641474279361043932140065048745733995,
#  2.528198568019286486511787485393395966532251851139528832851137550985275243582265146474599070857113733,
#  4.701857782553051989019272646029161009080572263309768249279578900283753195796140223167761331061193531,
#  -0.4702856259210250671625881418032554376249019550303872171206417484895011140628830786744283539213739778 - 0.1963516780671086217767146856006185748347243270138730142022999889991297833250794863108512396237987776*I,
# ...

# %%
a, b, c, d, e = sp.symbols('a b c d e')

P = (104976*R**12 - 629856*R**11 + 297432*R**10 + 1561032*R**9 + 452385*R**8
     - 840456*R**7 - 541476*R**6 + 53400*R**5 + 122758*R**4
     + 25320*R**3 - 3132*R**2 - 864*R + 81)

expr = (-2*sp.sqrt(3)*a*b*c - 2*a*T*c*d - R*T + R + sp.sqrt(3)*b*d*(R*T - R - T - 1) + T + 2*(T+1)**2*e + 1)


res_a = sp.resultant(expr, a**2 - R, a)
expr = sp.expand(res_a)

res_b = sp.resultant(expr, b**2 - T, b)
expr = sp.expand(res_b)

res_c = sp.resultant(expr, c**2 - (R + T + 1), c)
expr = sp.expand(res_c)

res_d = sp.resultant(expr, d**2 - (T + 2), d)
expr = sp.expand(res_d)

res_e = sp.resultant(expr, e**2 - (2*R + 1), e)
expr = sp.expand(res_e)

res_R = sp.resultant(expr, P, R)
res_R
# Out:
# *T**768 - *T**767 - *T**766 - 12914330928897867532582495274490279402882136246900987645388
# ...

# %%
_, factors = sp.factor_list(res_R)
factors
# Out:
# [(T + 1, 384),
#  (34263*T**12 + 4011444*T**11 - 17146890*T**10 - 577260*T**9 + 37508337*T**8 - 21434328*T**7 - 15305644*T**6 + 23296520*T**5 - 11230423*T**4 + 2057892*T**3 - 30186*T**2 - 3996*T - 81,
#   4),
#  (477567*T**12 - 112128348*T**11 + 152167094*T**10 + 2050922116*T**9 + 660791097*T**8 - 7329388920*T**7 - 12149238252*T**6 - 7332043032*T**5 - 655244319*T**4 + 1066510164*T**3 + 371765910*T**2 + 56430100*T - 32761,
#   4),
#  (1402911*T**12 - 51625932*T**11 - 565785754*T**10 + 1716767188*T**9 + 14344671465*T**8 + 22306724904*T**7 + 8637116532*T**6 + 570876552*T**5 - 445192095*T**4 - 81747420*T**3 + 3328134*T**2 + 1662244*T - 175561,
#   4),
#  (3008583*T**12 - 22938228*T**11 - 160464402*T**10 + 13736412*T**9 + 1441016073*T**8 + 3074176152*T**7 + 2545402244*T**6 + 844024728*T**5 + 32686281*T**4 - 29350948*T**3 - 2596242*T**2 + 1002636*T - 32761,
#   4),
# ...

# %%
sp.nroots(factors[-8][0], n=777, maxsteps=1000)
# Out:
# [-121....,
#  0....,
#  0....,
#  0....,
#  1....,
#  3....,
#  -1.... - 0....*I,
#  -1.... + 0....*I,
#  -0.... - 0....*I,
#  -0.... + 0....*I,
#  0.... - 0....*I,
#  0.... + 0....*I]

# %%
ft2 = factors[-8][0]
ft2
# Out:
# 34263*T**12 + 4011444*T**11 - 17146890*T**10 - 577260*T**9 + 37508337*T**8 - 21434328*T**7 - 15305644*T**6 + 23296520*T**5 - 11230423*T**4 + 2057892*T**3 - 30186*T**2 - 3996*T - 81

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

fr_clean = sp.expand(ft2)
f_lambd = sp.lambdify(T, fr_clean, "numpy")

x_vals = np.linspace(0.55, 0.57, 500)
y_vals = f_lambd(x_vals)

plt.figure(figsize=(8,5))
plt.plot(x_vals, y_vals, label="ft2(t)")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("t")
plt.ylabel("ft2(t)")
plt.title("График многочлена ft2(t)")
plt.legend()
plt.grid(True)
plt.show()

# %%
FS_num
# Out:
# -3*R*T + S**2 + S*(R + T)

# %%
r = 0....
t = 0....
s =(-(r+t)+sp.sqrt((r+t)*(r+t)+12*r*t)) / 2
print(r)
print(round(s,20))
print(t)
# Out:
# 0.7133077137962365
# 0.627458119719941
# 0.5562273486196635
